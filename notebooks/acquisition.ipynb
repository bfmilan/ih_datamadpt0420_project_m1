# %% [markdown]
# ### Data Acquisition

# %%
import pandas as pd
from sqlalchemy import create_engine
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# #### 1.1 Tables (.db)

# %%
sqlitepath = '../data/raw/raw_data_project_m1.db'
engine = create_engine(f'sqlite:///{sqlitepath}')

# %%
# Table summary
pd.read_sql_query("SELECT * from sqlite_master WHERE type = 'table'", engine)
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table  personal_info  personal_info         2
# 1  table   country_info   country_info       401
# 2  table    career_info    career_info       762
# 3  table      poll_info      poll_info      1168
#
#                                                  sql
# 0  CREATE TABLE personal_info (\n\tuuid TEXT NOT ...
# 1  CREATE TABLE country_info (\n\tuuid TEXT NOT N...
# 2  CREATE TABLE career_info (\n\tuuid TEXT NOT NU...
# 3  CREATE TABLE poll_info (\n\tuuid TEXT NOT NULL...

# %% [markdown]
# Get the tables -all in one

# %%
#all query
df_data_project = pd.read_sql_query("""SELECT * FROM career_info cif  
inner join poll_info pif on cif.uuid = pif.uuid  
inner join country_info ci on ci.uuid = pif.uuid 
inner join personal_info pi on pi.uuid = ci.uuid""",engine)
data_raw = pd.DataFrame(df_data_project)
data_raw
# Out:
#                                       uuid dem_education_level  \
# 0     f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no
# 1     54f0f1c0-dda1-0133-a559-0a81e8b09a82                high
# 2     83127080-da3d-0133-c74f-0a81e8b09a82                None
# 3     15626d40-db13-0133-ea5c-0a81e8b09a82                high
# 4     24954a70-db98-0133-4a64-0a81e8b09a82                high
# 5     28583060-dbe2-0133-ff9c-0a81e8b09a82                high
# 6     b50dbb80-da53-0133-8956-0a81e8b09a82              medium
# 7     dd743bb0-d9a5-0133-53b2-0a81e8b09a82              medium
# 8     4fde2370-da48-0133-3a42-0a81e8b09a82              medium
# 9     9949c4c0-da5f-0133-c832-0a81e8b09a82                  no
# 10    226cf850-db28-0133-c51a-0a81e8b09a82                high
# 11    69f1f400-dc5f-0133-ad9b-0a81e8b09a82              medium
# 12    2351fbe0-de4c-0133-0d58-0a81e8b09a82                 low
# 13    0f286c80-dd77-0133-7803-0a81e8b09a82              medium
# 14    fe54f360-db27-0133-c444-0a81e8b09a82              medium
# 15    960b1ce0-db01-0133-528c-0a81e8b09a82              medium
# 16    d7912480-da41-0133-5bc1-0a81e8b09a82                 low
# 17    d468c670-da40-0133-de39-0a81e8b09a82                high
# 18    76767d10-dd6c-0133-f56d-0a81e8b09a82                 low
# 19    a96ed910-de55-0133-2582-0a81e8b09a82              medium
# 20    68eace50-db46-0133-97f7-0a81e8b09a82                 low
# 21    aa342b50-dcc4-0133-f797-0a81e8b09a82              medium
# 22    638a8b80-da45-0133-e8e1-0a81e8b09a82                  no
# 23    b1eb3870-decd-0133-d783-0a81e8b09a82                None
# 24    1c8ea6b0-de3d-0133-605b-0a81e8b09a82                high
# 25    d31a5ea0-d969-0133-79f5-0a81e8b09a82              medium
# 26    2c1d6730-d970-0133-9161-0a81e8b09a82              medium
# 27    307ce090-daf9-0133-f4f2-0a81e8b09a82                 low
# 28    388a2f20-db3b-0133-570e-0a81e8b09a82              medium
# 28                      I know something about it
# 29                       I have never heard of it
# ...                                           ...
# 9619                        I understand it fully
# 9620          I have heard just a little about it
# 9621                    I know something about it
# 9622                     I have never heard of it
# 9623                     I have never heard of it
# 9624                        I understand it fully
# 9625                    I know something about it
# 9626                    I know something about it
# 9627                     I have never heard of it
# 9628                    I know something about it
# 9629                     I have never heard of it
# 9630          I have heard just a little about it
# 9631                     I have never heard of it
# 9632                     I have never heard of it
# 9633                        I understand it fully
# 9634                     I have never heard of it
# 9635                     I have never heard of it
# 9636                    I know something about it
# 9637                     I have never heard of it
# 9638          I have heard just a little about it
# 9639                     I have never heard of it
# 9640                    I know something about it
# 9641                     I have never heard of it
# 9642          I have heard just a little about it
# 9643                     I have never heard of it
# 9644                        I understand it fully
# 9645                     I have never heard of it
# 9646          I have heard just a little about it
# 9647                        I understand it fully
# 9648                        I understand it fully
#
#      question_bbi_2016wave4_basicincome_vote  \
# 0                           I would not vote
# 1               I would probably vote for it
# 2                           I would not vote
# 3               I would probably vote for it
# 4               I would probably vote for it
# 5                    I would vote against it
# 6               I would probably vote for it
# 7               I would probably vote for it
# 8               I would probably vote for it
# 9                        I would vote for it
# 10              I would probably vote for it
# 11              I would probably vote for it
# 12              I would probably vote for it
# 13                       I would vote for it
# 14              I would probably vote for it
# 15              I would probably vote for it
# 16                   I would vote against it
# 17              I would probably vote for it
# 18          I would probably vote against it
# 19          I would probably vote against it
# 20                       I would vote for it
# 21          I would probably vote against it
# 22              I would probably vote for it
# 23                       I would vote for it
# 24          I would probably vote against it
# 25              I would probably vote for it
# 26          I would probably vote against it
# 27          I would probably vote against it
# 28          I would probably vote against it
# 29                       I would vote for it
# ...                                      ...
# 9619                        I would not vote
# 9620                 I would vote against it
# 9621                 I would vote against it
# 9622            I would probably vote for it
# 9623        I would probably vote against it
# 9624            I would probably vote for it
# 9625            I would probably vote for it
# 9626                        I would not vote
# 9627        I would probably vote against it
# 9628            I would probably vote for it
# 9629                 I would vote against it
# 9630            I would probably vote for it
# 9631                        I would not vote
# 9632        I would probably vote against it
# 9633                     I would vote for it
# 9634                        I would not vote
# 9635                        I would not vote
# 9636            I would probably vote for it
# 9637                 I would vote against it
# 9638            I would probably vote for it
# 9639                     I would vote for it
# 9640                 I would vote against it
# 9641                        I would not vote
# 9642            I would probably vote for it
# 9643            I would probably vote for it
# 9644            I would probably vote for it
# 9645        I would probably vote against it
# 9646                        I would not vote
# 9647                     I would vote for it
# 9648                 I would vote against it
#
#             question_bbi_2016wave4_basicincome_effect  \
# 0                                   None of the above
# 1     A basic income would not affect my work choices
# 2                          ‰Û_ gain additional skills
# 3                                       ‰Û_ work less
# 4                                   None of the above
# 5     A basic income would not affect my work choices
# 6                            ‰Û_ work as a freelancer
# 7     A basic income would not affect my work choices
# 8                                   None of the above
# 9                       ‰Û_ do more volunteering work
# 10    A basic income would not affect my work choices
# 11                                   ‰Û_ stop working
# 12                         ‰Û_ gain additional skills
# 13    A basic income would not affect my work choices
# 14                         ‰Û_ gain additional skills
# 15    A basic income would not affect my work choices
# 16                                   ‰Û_ stop working
# 17                           ‰Û_ work as a freelancer
# 18                         ‰Û_ gain additional skills
# 19                                  None of the above
# 20                         ‰Û_ gain additional skills
# 21                         ‰Û_ gain additional skills
# 22                      ‰Û_ do more volunteering work
# 23    A basic income would not affect my work choices
# 24    A basic income would not affect my work choices
# 25    A basic income would not affect my work choices
# 26    A basic income would not affect my work choices
# 27                 ‰Û_ spend more time with my family
# 28                         ‰Û_ gain additional skills
# 29                                      ‰Û_ work less
# ...                                               ...
# 9619  A basic income would not affect my work choices
# 9620                     ‰Û_ look for a different job
# 9621                                    ‰Û_ work less
# 9622  A basic income would not affect my work choices
# 9623               ‰Û_ spend more time with my family
# 9624                    ‰Û_ do more volunteering work
# 9625                         ‰Û_ work as a freelancer
# 9626                                None of the above
# 9627  A basic income would not affect my work choices
# 9628                         ‰Û_ work as a freelancer
# 9629  A basic income would not affect my work choices
# 9630                                    ‰Û_ work less
# 9631                     ‰Û_ look for a different job
# 9632                                None of the above
# 9633                    ‰Û_ do more volunteering work
# 9634                    ‰Û_ do more volunteering work
# 9635                     ‰Û_ look for a different job
# 9636                       ‰Û_ gain additional skills
# 9637                                None of the above
# 9638               ‰Û_ spend more time with my family
# 9639  A basic income would not affect my work choices
# 9640  A basic income would not affect my work choices
# 9641               ‰Û_ spend more time with my family
# 9642                                None of the above
# 9643  A basic income would not affect my work choices
# 9644               ‰Û_ spend more time with my family
# 9645  A basic income would not affect my work choices
# 9646               ‰Û_ spend more time with my family
# 9647  A basic income would not affect my work choices
# 9648  A basic income would not affect my work choices
#
#         question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                     None of the above
# 1     It increases appreciation for household work a...
# 2               It creates more equality of opportunity
# 3        It reduces anxiety about financing basic needs
# 4        It reduces anxiety about financing basic needs
# 5     It encourages financial independence and self-...
# 6        It reduces anxiety about financing basic needs
# 7     It increases appreciation for household work a...
# 8     It creates more equality of opportunity | It r...
# 9     It increases solidarity, because it is funded ...
# 10       It reduces anxiety about financing basic needs
# 11    It increases appreciation for household work a...
# 12    It reduces anxiety about financing basic needs...
# 13              It creates more equality of opportunity
# 14       It reduces anxiety about financing basic needs
# 15       It reduces anxiety about financing basic needs
# 16    It encourages financial independence and self-...
# 17    It reduces anxiety about financing basic needs...
# 18              It creates more equality of opportunity
# 19       It reduces anxiety about financing basic needs
# 20    It increases solidarity, because it is funded ...
# 21    It increases appreciation for household work a...
# 22    It increases appreciation for household work a...
# 23    It reduces anxiety about financing basic needs...
# 24    It creates more equality of opportunity | It r...
# 25    It reduces anxiety about financing basic needs...
# 26    It encourages financial independence and self-...
# 27    It reduces anxiety about financing basic needs...
# 28    It reduces anxiety about financing basic needs...
# 29                                    None of the above
# ...                                                 ...
# 9619  It increases solidarity, because it is funded ...
# 9620                                  None of the above
# 9621                                  None of the above
# 9622     It reduces anxiety about financing basic needs
# 9623  It reduces bureaucracy and administrative expe...
# 9624  It reduces bureaucracy and administrative expe...
# 9625  It encourages financial independence and self-...
# 9626  It reduces bureaucracy and administrative expe...
# 9627  It increases solidarity, because it is funded ...
# 9628  It creates more equality of opportunity | It i...
# 9629                                  None of the above
# 22                 nO     14_25
# 23                 NO     14_25
# 24                 NO     26_39
# 25                YES     26_39
# 26                 NO     40_65
# 27                YES     40_65
# 28                yES     26_39
# 29                yES     40_65
# ...               ...       ...
# 9619               nO     26_39
# 9620               nO     26_39
# 9621               nO     26_39
# 9622              yES     40_65
# 9623              YES     26_39
# 9624               nO     14_25
# 9625               nO     26_39
# 9626              YES     26_39
# 9627               NO     40_65
# 9628              YES     26_39
# 9629              yES     40_65
# 9630              YES     26_39
# 9631              yES     14_25
# 9632              YES     40_65
# 9633               NO     26_39
# 9634               nO  juvenile
# 9635              YES     40_65
# 9636               nO     26_39
# 9637              YES     40_65
# 9638               nO     14_25
# 9639               nO     14_25
# 9640              yES     40_65
# 9641              yES     14_25
# 9642              yES     40_65
# 9643               nO     14_25
# 9644               nO     26_39
# 9645              yES     40_65
# 9646               NO  juvenile
# 9647              yES     40_65
# 9648              YES     40_65
#
# [9649 rows x 18 columns]

# %% [markdown]
# Get tables - one by one

# %%
# Table acquisition
df_personal_info = pd.read_sql_table('personal_info', engine)
df_country_info = pd.read_sql_table('country_info', engine)
df_career_info = pd.read_sql_table('career_info', engine)
df_poll_info = pd.read_sql_table('poll_info', engine)

# %% [raw]
# #personal info
# df_personal = pd.read_sql_query("select * from personal_info", engine)
# df_personal
#
# df_country = pd.read_sql_query("select * from country_info", engine)
# df_country
#
# df_career = pd.read_sql_query("select * from career_info", engine)
# df_career
#
# df_poll = pd.read_sql_query("select * from poll_info", engine)
# df_poll

# %% [markdown]
# Tables summary

# %%
print(f'Table: Personal info\nRows: {df_personal_info.shape[0]} \nColumns: {df_personal_info.shape[1]}\n\nNull values:\n{df_personal_info.isnull().sum()}')
# Out:
# Table: Personal info
# Rows: 9649
# Columns: 5
#
# Null values:
# uuid                0
# age                 0
# gender              0
# dem_has_children    0
# age_group           0
# dtype: int64

# %%
# save in csv 
df_personal_info.to_csv('../data/raw/personal_info.csv')

# %%
##### 1.1.2 Country info table

# %%
print(f'Table: Country info\nRows: {df_country_info.shape[0]} \nColumns: {df_country_info.shape[1]}\n\nNull values:\n{df_country_info.isnull().sum()}')
# Out:
# Table: Country info
# Rows: 9649
# Columns: 3
#
# Null values:
# uuid            0
# country_code    0
# rural           0
# dtype: int64

# %%
df_country_info.to_csv('../data/raw/country_info.csv')

# %%
print(f'Table: Career info\nRows: {df_career_info.shape[0]} \nColumns: {df_career_info.shape[1]}\n\nNull values:\n{df_career_info.isnull().sum()}')
# Out:
# Table: Career info
# Rows: 9649
# Columns: 4
#
# Null values:
# uuid                      0
# dem_education_level     663
# dem_full_time_job         0
# normalized_job_code    3947
# dtype: int64

# %% [markdown]
# Career table has Null values for dem_education_level (663) and normalized_job_code (3947) - \n
# We need to take care of the ones from normalized_job_code before we save

# %%
# Easiest way is Null to string 'None'
df_career_info['normalized_job_code'].fillna('None', inplace=True)

# %%
df_career_info.to_csv('../data/raw/career_info.csv')

# %%
print(f'Table: Poll info\nRows: {df_poll_info.shape[0]} \nColumns: {df_poll_info.shape[1]}\n\nNull values:\n{df_poll_info.isnull().sum()}')
# Out:
# Table: Poll info
# Rows: 9649
# Columns: 6
#
# Null values:
# uuid                                                   0
# question_bbi_2016wave4_basicincome_awareness           0
# question_bbi_2016wave4_basicincome_vote                0
# question_bbi_2016wave4_basicincome_effect              0
# question_bbi_2016wave4_basicincome_argumentsfor        0
# question_bbi_2016wave4_basicincome_argumentsagainst    0
# dtype: int64

# %% [raw]
# # would love to make a loop here
# # tables = ['df_personal_info','df_country_info','df_career_info','df_poll_info']
# '''
# for table in tables:
#     print(tables[table].shape)
#     print(tables[table].dtypes)
#     print(list(tables[table]))
# for table in tables:
#     print(("{}".format(table)), f'Table: info\nRows: {df_career_info.shape[0]} \nColumns: {df_career_info.shape[1]}')
#     print({table}.shape)

# %%
df_poll_info.to_csv('../data/raw/poll_info.csv')

# %% [markdown]
# #### 1.2 Check final outputs

# %%
display(df_career_info.head(5))
# Out:
#                                    uuid dem_education_level dem_full_time_job  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82                  no                no
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82                high               yes
# 2  83127080-da3d-0133-c74f-0a81e8b09a82                None                no
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82                high               yes
# 4  24954a70-db98-0133-4a64-0a81e8b09a82                high               yes
#
#                 normalized_job_code
# 0                              None
# 1  861a9b9151e11362eb3c77ca914172d0
# 2                              None
# 3  049a3f3a2b5f85cb2971ba77ad66e10c
# 4  f4b2fb1aa40f661488e2782b6d57ad2f

# %%
display(df_country_info.head(5))
# Out:
#                                    uuid country_code        rural
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82           AT  countryside
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82           AT        urban
# 2  83127080-da3d-0133-c74f-0a81e8b09a82           AT         city
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82           AT      Country
# 4  24954a70-db98-0133-4a64-0a81e8b09a82           AT         city

# %%
display(df_personal_info.head(5))
# Out:
#                                    uuid           age gender dem_has_children  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82  61 years old   male               NO
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82  57 years old   male              yES
# 2  83127080-da3d-0133-c74f-0a81e8b09a82  32 years old   male               nO
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82  45 years old   Male              YES
# 4  24954a70-db98-0133-4a64-0a81e8b09a82  41 years old    Fem              yES
#
#   age_group
# 0     40_65
# 1     40_65
# 2     26_39
# 3     40_65
# 4     40_65

# %%
display(df_poll_info.head(5))
# Out:
#                                    uuid  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82
# 2  83127080-da3d-0133-c74f-0a81e8b09a82
# 3  15626d40-db13-0133-ea5c-0a81e8b09a82
# 4  24954a70-db98-0133-4a64-0a81e8b09a82
#
#   question_bbi_2016wave4_basicincome_awareness  \
# 0                    I know something about it
# 1                        I understand it fully
# 2          I have heard just a little about it
# 3          I have heard just a little about it
# 4          I have heard just a little about it
#
#   question_bbi_2016wave4_basicincome_vote  \
# 0                        I would not vote
# 1            I would probably vote for it
# 2                        I would not vote
# 3            I would probably vote for it
# 4            I would probably vote for it
#
#          question_bbi_2016wave4_basicincome_effect  \
# 0                                None of the above
# 1  A basic income would not affect my work choices
# 2                       ‰Û_ gain additional skills
# 3                                    ‰Û_ work less
# 4                                None of the above
#
#      question_bbi_2016wave4_basicincome_argumentsfor  \
# 0                                  None of the above
# 1  It increases appreciation for household work a...
# 2            It creates more equality of opportunity
# 3     It reduces anxiety about financing basic needs
# 4     It reduces anxiety about financing basic needs
#
#   question_bbi_2016wave4_basicincome_argumentsagainst
# 0                                  None of the above
# 1          It might encourage people to stop working
# 2  Foreigners might come to my country and take a...
# 3                                  None of the above
# 4  It is impossible to finance | It might encoura...

# %% [markdown]
# #### 1.2 API. We will use the API from the Open Skills Project

# %% [markdown]
# First we need to get the job codes [unique values] from the career info df so we can call merge with api - normalized job codes

# %% [markdown]
# Option 1

# %%
jobs_api = []
job_codes = set(df_career_info['normalized_job_code'])
# job_codes = df_career_info['normalized_job_code'].unique().tolist()

# %%
# get job codes on a loop
for i in job_codes:
    response = requests.get(f'http://api.dataatwork.org/v1/jobs/{i}')
    jobs_json = response.json()
    jobs_api.append(jobs_json)
# jobs_api

# %%
jobs = pd.DataFrame(jobs_api).rename(columns = {'uuid':'normalized_job_code'})[['normalized_job_code', 'title', 'normalized_job_title']]

# %%
jobs.shape
# Out:
# (314, 3)

# %% [markdown]
# Option 2

# %%
jobs_api2 = []
job_codes2 = df_career_info['normalized_job_code'].unique().tolist()
for i in job_codes2:
    response = requests.get(f'http://api.dataatwork.org/v1/jobs/{i}')
    jobs_json2 = response.json()
    jobs_api2.append(jobs_json2)

# %%
jobs2 = pd.DataFrame(jobs_api2).rename(columns = {'uuid':'normalized_job_code'})[['normalized_job_code', 'title', 'normalized_job_title']]

# %%
jobs2.shape
# Out:
# (157, 3)

# %% [markdown]
# Option 1 (314, 3) vs Option 2 (157, 3) - Option 1 gets unique values as we need

# %%
# pd.DataFrame(norm_job_dic.items(), columns = ['normalized_job_code', 'title']).to_parquet('../data/raw/norm_job_codes-names.parquet')

# %% [markdown]
# #### 1.3 Webscrapping

# %% [markdown]
# Finally, we will need to retrieve information about country codes from Eurostat website.

# %% [markdown]
# 1.3.1 Api Country Codes - More info available here: https://github.com/apilayer/restcountries and Api available here: https://restcountries.eu/rest/v2/alpha/{code}

# %%
country_api = []
country_code_list = df_country_info['country_code'].unique().tolist()

# %%
for i in country_code_list:
    response = requests.get(f'https://restcountries.eu/rest/v2/alpha/{i}')
    country_json = response.json()
    country_api.append(country_json)
# country_api
# More info available https://github.com/apilayer/restcountries
# country_api

# %%
country_api_code = pd.DataFrame(country_api).rename(columns = {'name':'country_name', 'alpha2Code': 'country_code','alpha3Code': 'country_code2'})[['country_name', 'country_code', 'country_code2']]
# country_api_code

# %%
country_api_code.to_csv('../data/raw/data_countries_api.csv')

# %% [markdown]
# #### Save to CSV

# %%
path = '../data/raw/'
data_raw.to_csv(f'{path}data_raw.csv')
country_api_code.to_csv(f'{path}data_countries_api.csv')
jobs2.to_csv(f'{path}data_jobs_api.csv')
